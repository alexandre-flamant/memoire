# %% [markdown]
# # Import libraries and open data

# %%
from default import *
# %cd -q {PROJECT_HOME}

from dataset import FixedPrattTrussDatasetSingleTarget
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import numpy as np

# Set dataset dirs
train_dataset_dir = r"data/dataset/pratt_truss_bridge_isostatic/0_uniform_ea"
test_dataset_dir = r"data/dataset/pratt_truss_bridge_isostatic/test"

# %%
def convert_dataset(filepath):
    ds = FixedPrattTrussDatasetSingleTarget(filepath)

    X = []
    y = []

    for data in ds:
        x_i, y_i, _, _, _ = data
        X.append(x_i)
        y.append(y_i)

    return np.array(X), np.array(y)


X_train, y_train = convert_dataset(f"{train_dataset_dir}/train_4096.hdf5")
X_validation, y_validation = convert_dataset(f"{test_dataset_dir}/uniform_8192.hdf5")

# %% [markdown]
# # Regression

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error, make_scorer
from scipy.stats import loguniform, uniform
import numpy as np

# Define pipeline
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),
    ('pca', PCA(n_components=0.95)),
    ('regression', LinearRegression())
])

# Define search space
param_distributions = {
    'pca__n_components': uniform(0, 1)
}

# Halving Random Search CV
search = HalvingRandomSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    scoring="neg_mean_absolute_percentage_error",
    n_candidates=1000,
    factor=3,
    random_state=42,
    cv=10,
    n_jobs=-1
)

# Fit the search
search.fit(X_train, y_train)

# Best model
best_pipeline = search.best_estimator_

# Predict
y_train_pred = best_pipeline.predict(X_train)
y_val_pred = best_pipeline.predict(X_validation)

# Metrics function
def compute_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true * 1e-6, y_pred * 1e-6)  # MSE in millions
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    return r2, mse, rmse, mape

# Compute metrics
r2_train, mse_train, rmse_train, mape_train = compute_metrics(y_train, y_train_pred)
r2_val, mse_val, rmse_val, mape_val = compute_metrics(y_validation, y_val_pred)

# Print results
print("=== BEST HYPERPARAMETERS ===")
print(search.best_params_)

print("\n=== TRAIN SET ===")
print(f"R2     : {r2_train:.4f}")
print(f"MSE    : {mse_train:.4f} MN^2")
print(f"RMSE   : {rmse_train:.4f} MN^2")
print(f"MAPE   : {mape_train:.4%}")

print("\n=== VALIDATION SET ===")
print(f"R2     : {r2_val:.4f}")
print(f"MSE    : {mse_val:.4f} MN^2")
print(f"RMSE   : {rmse_val:.4f} MN")
print(f"MAPE   : {mape_val:.4%}")
# Out:
# === BEST HYPERPARAMETERS ===
# {'pca__n_components': 0.7607850486168974}
#
# === TRAIN SET ===
# R2     : 0.3280
# MSE    : 5856027.5000 MN^2
# RMSE   : 2419.9231 MN^2
# MAPE   : 98.8529%
#
# === VALIDATION SET ===
# R2     : 0.3188
# MSE    : 5933212.0000 MN^2
# RMSE   : 2435.8186 MN
# MAPE   : 99.9747%

# %% [markdown]
# # Ridge regression

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error, make_scorer
from scipy.stats import loguniform, uniform
import numpy as np

# Define pipeline
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),
    ('pca', PCA(n_components=0.95)),
    ('regression', Ridge())
])

# Define search space
param_distributions = {
    'pca__n_components': uniform(0, 1),
    'regression__alpha': loguniform(1e-6, 1e4)
}

# Halving Random Search CV
search = HalvingRandomSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    scoring="neg_mean_absolute_percentage_error",
    n_candidates=1000,
    factor=3,
    random_state=42,
    cv=10,
    n_jobs=-1
)

# Fit the search
search.fit(X_train, y_train)

# Best model
best_pipeline = search.best_estimator_

# Predict
y_train_pred = best_pipeline.predict(X_train)
y_val_pred = best_pipeline.predict(X_validation)

# Metrics function
def compute_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true * 1e-6, y_pred * 1e-6)  # MSE in millions
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    return r2, mse, rmse, mape

# Compute metrics
r2_train, mse_train, rmse_train, mape_train = compute_metrics(y_train, y_train_pred)
r2_val, mse_val, rmse_val, mape_val = compute_metrics(y_validation, y_val_pred)

# Print results
print("=== BEST HYPERPARAMETERS ===")
print(search.best_params_)

print("\n=== TRAIN SET ===")
print(f"R2     : {r2_train:.4f}")
print(f"MSE    : {mse_train:.4f} MN^2")
print(f"RMSE   : {rmse_train:.4f} MN^2")
print(f"MAPE   : {mape_train:.4%}")

print("\n=== VALIDATION SET ===")
print(f"R2     : {r2_val:.4f}")
print(f"MSE    : {mse_val:.4f} MN^2")
print(f"RMSE   : {rmse_val:.4f} MN")
print(f"MAPE   : {mape_val:.4%}")
# Out:
# === BEST HYPERPARAMETERS ===
# {'pca__n_components': 0.9446142194740232, 'regression__alpha': 6.799551741277519}
#
# === TRAIN SET ===
# R2     : 0.3348
# MSE    : 5797111.5000 MN^2
# RMSE   : 2407.7192 MN^2
# MAPE   : 98.4369%
#
# === VALIDATION SET ===
# R2     : 0.3255
# MSE    : 5874749.0000 MN^2
# RMSE   : 2423.7881 MN
# MAPE   : 99.9182%

# %% [markdown]
# # Lasso

# %%
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Lasso
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error
from scipy.stats import loguniform
import numpy as np

# Define pipeline with Lasso instead of Ridge
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),
    ('pca', PCA(n_components=0.95)),
    ('regression', Lasso(max_iter=10000))
])

# Define hyperparameter search space
param_distributions = {
    'pca__n_components': uniform(0, 1),
    'regression__alpha': loguniform(1e-6, 1e4)
}

# Halving Random Search CV optimizing for MAPE
search = HalvingRandomSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    scoring="neg_mean_absolute_percentage_error",
    n_candidates=1000,
    factor=3,
    random_state=42,
    cv=10,
    n_jobs=-1
)

# Fit the model
search.fit(X_train, y_train)

# Best model
best_pipeline = search.best_estimator_

# Predict
y_train_pred = best_pipeline.predict(X_train)
y_val_pred = best_pipeline.predict(X_validation)

# Evaluation metrics
def compute_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mse = mean_squared_error(y_true * 1e-6, y_pred * 1e-6)  # MSE in MN²
    rmse = np.sqrt(mse)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    return r2, mse, rmse, mape

# Compute train/val metrics
r2_train, mse_train, rmse_train, mape_train = compute_metrics(y_train, y_train_pred)
r2_val, mse_val, rmse_val, mape_val = compute_metrics(y_validation, y_val_pred)

# Display results
print("=== BEST HYPERPARAMETERS ===")
print(search.best_params_)

print("\n=== TRAIN SET ===")
print(f"R2     : {r2_train:.4f}")
print(f"MSE    : {mse_train:.4f} MN²")
print(f"RMSE   : {rmse_train:.4f} MN")
print(f"MAPE   : {mape_train:.4%}")

print("\n=== VALIDATION SET ===")
print(f"R2     : {r2_val:.4f}")
print(f"MSE    : {mse_val:.4f} MN²")
print(f"RMSE   : {rmse_val:.4f} MN")
print(f"MAPE   : {mape_val:.4%}")
# Out:
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.647e+17, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.647e+17, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.585e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.862e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.007e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.585e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.055e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.004e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.309e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.297e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.641e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.309e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.308e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.924e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.499e+18, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.549e+17, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.211e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.307e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.308e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.723e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.300e+18, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.745e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.405e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.723e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.190e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.405e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.140e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.457e+17, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.269e+16, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.457e+17, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.360e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.899e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.387e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.294e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.265e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.298e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.019e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.924e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.224e+16, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.307e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.078e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.387e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.853e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.597e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.066e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.597e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.069e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.354e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.871e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.354e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.305e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.924e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.366e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.923e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.364e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.259e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.307e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.307e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.922e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.510e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.306e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.354e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.510e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.666e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.409e+17, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.357e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.649e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.409e+17, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.598e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.357e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.961e+19, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.598e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.600e+19, tolerance: 1.697e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.882e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.069e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.079e+19, tolerance: 1.882e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.072e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.083e+19, tolerance: 1.880e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.305e+19, tolerance: 1.497e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.924e+19, tolerance: 1.475e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.786e+17, tolerance: 1.763e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.083e+19, tolerance: 1.874e+16
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.365e+19, tolerance: 1.560e+16
# ...
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.280e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.372e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.220e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.412e+21, tolerance: 1.301e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.204e+21, tolerance: 1.292e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.205e+21, tolerance: 1.292e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.265e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.280e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.441e+21, tolerance: 1.290e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.279e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.372e+21, tolerance: 1.276e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.221e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.269e+21, tolerance: 1.248e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.442e+21, tolerance: 1.290e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.373e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.254e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.404e+21, tolerance: 1.301e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.206e+21, tolerance: 1.292e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.222e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.374e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.372e+21, tolerance: 1.276e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.278e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.413e+21, tolerance: 1.301e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.372e+21, tolerance: 1.276e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.443e+21, tolerance: 1.290e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.282e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.279e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.270e+21, tolerance: 1.248e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.264e+21, tolerance: 1.248e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.266e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.413e+21, tolerance: 1.301e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.222e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.374e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.443e+21, tolerance: 1.290e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.206e+21, tolerance: 1.292e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.280e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.266e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.282e+21, tolerance: 1.275e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.270e+21, tolerance: 1.248e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.372e+21, tolerance: 1.276e+18
#   model = cd_fast.enet_coordinate_descent(
# /Users/aflamant/miniconda3/envs/memoire/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.280e+21, tolerance: 1.249e+18
#   model = cd_fast.enet_coordinate_descent(
# === BEST HYPERPARAMETERS ===
# {'pca__n_components': 0.7506147516408583, 'regression__alpha': 117.04352492209394}
#
# === TRAIN SET ===
# R2     : 0.3280
# MSE    : 5856028.0000 MN²
# RMSE   : 2419.9231 MN
# MAPE   : 98.8529%
#
# === VALIDATION SET ===
# R2     : 0.3188
# MSE    : 5933212.5000 MN²
# RMSE   : 2435.8186 MN
# MAPE   : 99.9748%
